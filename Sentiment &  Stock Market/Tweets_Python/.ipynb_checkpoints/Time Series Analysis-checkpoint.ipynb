# %%
# %matplotlib inline
import pandas as pd
from fbprophet import Prophet

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-6a86467b793c> in <module>()
#       1 get_ipython().magic('matplotlib inline')
#       2 import pandas as pd
# ----> 3 from fbprophet import Prophet
#       4
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
df =pd.read_csv('Tata_Motors.csv')
df.head(5)
print(df.dtypes)
df.head(5)
# Out:
# Unnamed: 0            int64
# disease+AF8-type     object
# sentiment            object
# timestamp            object
# user+AF8-location    object
# dtype: object
#    Unnamed: 0 disease+AF8-type sentiment           timestamp user+AF8-location
# 0          25           dengue         0  2016+AC0-06+AC0-12      Bhopal India
# 1          26           dengue         0  2016+AC0-07+AC0-12             India
# 2          27           dengue         0  2016+AC0-08+AC0-12     Gwalior India
# 3          28           dengue         1  2016+AC0-09+AC0-12             India
# 4          29           dengue    +AC0-1  2016+AC0-10+AC0-12      Indore India

# %%
df['Date'] = pd.DatetimeIndex(df['timestamp'])
del df['timestamp']
del df['disease_type']
del df['user_location']
for col in df.columns:
    if 'Unnamed' in col:
        del df[col]
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.conda/envs/py36tensor/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-e310e5c487c6> in <module>()
# ----> 1 df['Date'] = pd.DatetimeIndex(df['timestamp'])
#       2 del df['timestamp']
#       3 del df['disease_type']
#       4 del df['user_location']
#       5 for col in df.columns:
#
# ~/.conda/envs/py36tensor/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/.conda/envs/py36tensor/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py in __new__(cls, data, freq, start, end, periods, copy, name, tz, verify_integrity, normalize, closed, ambiguous, dtype, **kwargs)
#     342                 is_integer_dtype(data)):
#     343             data = tools.to_datetime(data, dayfirst=dayfirst,
# --> 344                                      yearfirst=yearfirst)
#     345
#     346         if issubclass(data.dtype.type, np.datetime64) or is_datetimetz(data):
#
# ~/.conda/envs/py36tensor/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     378         result = _convert_listlike(arg, box, format, name=arg.name)
#     379     elif is_list_like(arg):
# --> 380         result = _convert_listlike(arg, box, format)
#     381     else:
#     382         result = _convert_listlike(np.array([arg]), box, format)[0]
#
# ~/.conda/envs/py36tensor/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     305             except (ValueError, TypeError):
# --> 306                 raise e
#     307
#     308     if arg is None:
#
# ~/.conda/envs/py36tensor/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     292                     dayfirst=dayfirst,
#     293                     yearfirst=yearfirst,
# --> 294                     require_iso8601=require_iso8601
#     295                 )
#     296
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/.conda/envs/py36tensor/lib/python3.6/site-packages/dateutil/parser.py in parse(timestr, parserinfo, **kwargs)
#    1180         return parser(parserinfo).parse(timestr, **kwargs)
#    1181     else:
# -> 1182         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1183
#    1184
#
# ~/.conda/envs/py36tensor/lib/python3.6/site-packages/dateutil/parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     557
#     558         if res is None:
# --> 559             raise ValueError("Unknown string format")
#     560
#     561         if len(res) == 0:
#
# ValueError: Unknown string format

# %%
df = df.rename(columns={'Date': 'ds',
                        'sentiment': 'y'})

# %%
df.head(5)
# Out:
#    y         ds
# 0  0 2017-11-12
# 1  0 2017-11-12
# 2 -1 2017-11-12
# 3  1 2017-11-12
# 4  0 2017-11-12

# %%
ax = df.set_index('ds').plot(figsize=(12, 8))

ax

# %%
ax.set_ylabel('Sentiment')
ax.set_xlabel('Date')

plt.show()

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width=0.95)

# %%
my_model.fit(df)
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_dates = my_model.make_future_dataframe(periods=9, freq='MS')
future_dates
# Out:
#             ds
# 0   2002-12-29
# 1   2003-01-05
# 2   2003-01-12
# 3   2003-01-19
# 4   2003-01-26
# 5   2003-02-02
# 6   2003-02-09
# 7   2003-02-16
# 8   2003-02-23
# 9   2003-03-02
# 10  2003-03-09
# 11  2003-03-16
# 12  2003-03-23
# 13  2003-03-30
# 14  2003-04-06
# 15  2003-04-13
# 16  2003-04-20
# 17  2003-04-27
# 18  2003-05-04
# 19  2003-05-11
# 20  2003-05-18
# 21  2003-05-25
# 22  2003-06-01
# 23  2003-06-08
# 24  2003-06-15
# 25  2003-06-22
# 26  2003-06-29
# 27  2003-07-06
# 28  2003-07-13
# 29  2003-07-20
# ..         ...
# 638 2015-03-22
# 639 2015-03-29
# 640 2015-04-05
# 641 2015-04-12
# 642 2015-04-19
# 643 2015-04-26
# 644 2015-05-03
# 645 2015-05-10
# 646 2015-05-17
# 647 2015-05-24
# 648 2015-05-31
# 649 2015-06-07
# 650 2015-06-14
# 651 2015-06-21
# 652 2015-06-28
# 653 2015-07-05
# 654 2015-07-12
# 655 2015-07-19
# 656 2015-07-26
# 657 2015-08-02
# 658 2015-08-09
# 659 2015-09-01
# 660 2015-10-01
# 661 2015-11-01
# 662 2015-12-01
# 663 2016-01-01
# 664 2016-02-01
# 665 2016-03-01
# 666 2016-04-01
# 667 2016-05-01
#
# [668 rows x 1 columns]

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 0   2002-12-29  0.075524   -0.120409    0.280854
# 1   2003-01-05  0.072220   -0.113666    0.271540
# 2   2003-01-12  0.064220   -0.122878    0.255145
# 3   2003-01-19  0.053931   -0.124203    0.259270
# 4   2003-01-26  0.046960   -0.154034    0.250191
# 5   2003-02-02  0.044800   -0.148330    0.238736
# 6   2003-02-09  0.043582   -0.163040    0.250012
# 7   2003-02-16  0.039574   -0.153212    0.236732
# 8   2003-02-23  0.033754   -0.172414    0.229725
# 9   2003-03-02  0.029863   -0.151053    0.229231
# 10  2003-03-09  0.029252   -0.170406    0.227131
